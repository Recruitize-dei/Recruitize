# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen 
import requests

# %%
links=[]

# %%
headers_std = {
'User-Agent': 'Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; Googlebot/2.1; +http://www.google.com/bot.html) Safari/537.36',
}
for page in range(0,10,10):
    print("Scraping page=", page)
    url="https://www.google.com/search?q=site:linkedin.com/in/+AND++%22dayalbagh%22+AND+%22engineering%22&rlz=1C1CHBF_enIN799IN799&sxsrf=ALeKk02hTQh1vtjJzJpbAoxQ56ceShHrjQ:1591892189149&ei=3VjiXtPZCJX8wAOChrmgCg&start="+str(page)+"&sa=N&ved=2ahUKEwiTvNHDlPrpAhUVPnAKHQJDDqQQ8tMDegQICxAt&biw=1707&bih=781"
    html = requests.get(url,headers=headers_std).text
    soup = BeautifulSoup(html,'html.parser')
    table  = soup.select(".r a")
    for i in table:
        l=i.get('href')
        print("Working")
        if(l.startswith('https://in.linkedin.com/in/')):
            links.append(l)
            print(l)
    
##Google has blocked my bot, tried changing username but no avail
# Out:
# Scraping page= 0

# %%
df = pd.DataFrame({'Profile Links':links}) 
df.to_csv('profile links.csv', mode='a',index=False, header=False)

# %%
for i1 in links:
    print(i1)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en-IN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    site:linkedin.com/in/ AND  "dayalbagh" AND "engineering" - Google Search
#   </title>
#   <script nonce="h3kBgo/VFgVrz6UBlWheaA==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...
