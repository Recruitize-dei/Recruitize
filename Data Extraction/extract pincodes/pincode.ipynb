# %%
import csv, json
import pandas as pd
df=pd.read_csv("pincode.csv")

# %%
rows=df.loc[df['pincode'] == 282005]
type(rows)
rows
# Out:
#         pincode divisionname regionname     circlename Taluk Districtname  \
# 125464   282005         Agra       Agra  Uttar Pradesh   NaN         Agra
# 125513   282005         Agra       Agra  Uttar Pradesh   NaN         Agra
# 125528   282005         Agra       Agra  Uttar Pradesh   NaN         Agra
# 125542   282005         Agra       Agra  Uttar Pradesh  Agra         Agra
# 125568   282005         Agra       Agra  Uttar Pradesh   NaN         Agra
# 125611   282005         Agra       Agra  Uttar Pradesh   NaN         Agra
#
#             statename
# 125464  UTTAR PRADESH
# 125513  UTTAR PRADESH
# 125528  UTTAR PRADESH
# 125542  UTTAR PRADESH
# 125568  UTTAR PRADESH
# 125611  UTTAR PRADESH

# %%
df
# Out:
#         divisionname    regionname      circlename        Taluk  \
# pincode
# 504273      Adilabad     Hyderabad  Andhra Pradesh     Asifabad
# 504293      Adilabad     Hyderabad  Andhra Pradesh     Asifabad
# 504307      Adilabad     Hyderabad  Andhra Pradesh        Boath
# 504001      Adilabad     Hyderabad  Andhra Pradesh     Adilabad
# 504001      Adilabad     Hyderabad  Andhra Pradesh     Adilabad
# ...              ...           ...             ...          ...
# 721649        Tamluk  South Bengal     West Bengal   Nandakumar
# 721151        Tamluk  South Bengal     West Bengal   Panskura-i
# 721626        Tamluk  South Bengal     West Bengal  Bhagawanpur
# 721139        Tamluk  South Bengal     West Bengal   Panskura-i
# 721648        Tamluk  South Bengal     West Bengal   Nandakumar
#
#            Districtname    statename
# pincode
# 504273         Adilabad    TELANGANA
# 504293         Adilabad    TELANGANA
# 504307         Adilabad    TELANGANA
# ...

# %%
GET https://api.postalpincode.in/pincode/110001
# Out:
#   File "<ipython-input-8-8da5f4b14f08>", line 1
#     GET https://api.postalpincode.in/pincode/110001
#             ^
# SyntaxError: invalid syntax

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
zipcode1 = "282007"
print("\nZipcode:",zipcode1)
location = geolocator.geocode(zipcode1)
print(location)
# Out:
# Zipcode: 282007
# {'place_id': 216581712, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 657262606, 'boundingbox': ['27.2063493', '27.2068025', '77.9718196', '77.9722795'], 'lat': '27.206575899999997', 'lon': '77.97204955000001', 'display_name': 'Bodla, आगरा - Agra, Agra, Uttar Pradesh, 282007, India', 'class': 'place', 'type': 'postcode', 'importance': 0.33499999999999996}

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen 
import requests
import csv
import time
import io
import json

# %%
headers_std = {
'User-Agent': 'Mozilla/5.0 AppleWebKit/537.36 (KHTML, like Gecko; compatible; Googlebot/2.1; +http://www.google.com/bot.html) Safari/537.36',
}
import requests
resp = requests.get("https://pincode.saratchandra.in/api/pincode/282005")

print(resp.json())
# Out:
# {'status': 200, 'data': [{'pincode': '282005', 'office_name': 'Dayal Bagh S.O', 'delivery_status': 'Delivery', 'division_name': 'Agra', 'region_name': 'Agra', 'circle_name': 'Uttar Pradesh', 'district': 'Agra', 'state_name': 'UTTAR PRADESH', 'taluk': 'NA'}, {'pincode': '282005', 'office_name': 'Jaganpur B.O', 'delivery_status': 'Delivery', 'division_name': 'Agra', 'region_name': 'Agra', 'circle_name': 'Uttar Pradesh', 'district': 'Agra', 'state_name': 'UTTAR PRADESH', 'taluk': 'NA'}, {'pincode': '282005', 'office_name': 'K.H.Sansthan S.O', 'delivery_status': 'Non-Delivery', 'division_name': 'Agra', 'region_name': 'Agra', 'circle_name': 'Uttar Pradesh', 'district': 'Agra', 'state_name': 'UTTAR PRADESH', 'taluk': 'NA'}, {'pincode': '282005', 'office_name': 'Karmyogi Enclave S.O', 'delivery_status': 'Non-Delivery', 'division_name': 'Agra', 'region_name': 'Agra', 'circle_name': 'Uttar Pradesh', 'district': 'Agra', 'state_name': 'UTTAR PRADESH', 'taluk': 'Agra'}, {'pincode': '282005', 'of
# ...

# %%
data={}

with open("pincode.csv") as csvFile:
    csvReader=csv.DictReader(csvFile)
    for rows in csvReader:
        id=rows['pincode']
        data[id]=rows
print(data)
